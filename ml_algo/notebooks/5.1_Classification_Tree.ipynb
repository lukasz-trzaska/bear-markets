# %% [markdown]
# <b>Import libraries

# %%
import pickle
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from plotly.subplots import make_subplots
from sklearn import tree
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.feature_selection import (RFE, SelectFromModel, SelectKBest,
                                       SequentialFeatureSelector,
                                       VarianceThreshold, chi2, f_classif,
                                       mutual_info_classif)
from sklearn.metrics import (auc, classification_report, confusion_matrix,
                             precision_recall_curve, roc_auc_score, roc_curve)
from sklearn.model_selection import (GridSearchCV, StratifiedKFold,
                                     cross_val_score)
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier

from diagnostics import ClassificationDiagnostics  # custom class
from minmaxscaler import mmscaler  # custom function

# %% [markdown]
# <b>Import dataset

# %%
DATA_PATH = os.path.join(Path(os.getcwd()).parent, "data\\train_set.pkl")

# %%
with open(DATA_PATH,"rb") as f:
    df = pickle.load(f)
df
# Out:
#             Date     Index  daily_returns  momentum30  momentum60  \
# 0     2010-06-25  4.579647       0.545185   98.852998   99.186729
# 1     2010-06-28  4.580263       0.061532   99.368701   99.155543
# 2     2010-06-29  4.537961      -4.230111   98.279685   97.914172
# 3     2010-06-30  4.523635      -1.432674   98.375237   97.596871
# 4     2010-07-01  4.522223      -0.141143   98.439591   97.601193
# ...          ...       ...            ...         ...         ...
# 2896  2021-12-27  7.338830       2.007130  100.490500  101.924288
# 2897  2021-12-28  7.334336      -0.449377  100.309045  101.708571
# 2898  2021-12-29  7.337347       0.301111  100.382438  102.028622
# 2899  2021-12-30  7.330857      -0.648971  100.167129  101.782684
# 2900  2021-12-31  7.328201      -0.265632  100.216998  101.758857
#
#       momentum120  vs_quantile  vs_quantile_binary  vs_quantile_binary_freq  \
# 0       99.445776     0.148886                 0.0                 0.083333
# 1       99.465618     0.141364                 0.0                 0.083333
# 2       98.598467    -1.823472                 1.0                 0.100000
# 3       98.342961    -0.228739                 0.0                 0.100000
# 4       98.128629     0.136183                 0.0                 0.100000
# ...           ...          ...                 ...                      ...
# 2896   101.959527     0.445107                 0.0                 0.033333
# 2897   102.030084     0.113669                 0.0                 0.033333
# 2898   101.880797     0.137352                 0.0                 0.033333
# 2899   101.794794     0.093081                 0.0                 0.033333
# 2900   101.818318     0.142593                 0.0                 0.033333
#
#       divergence  lag_returns  sell_signal
# 0      -0.030905    -2.193406            1
# 1      -0.031225     0.545185            1
# 2      -0.032261     0.061532            1
# 3      -0.032895    -4.230111            1
# 4      -0.033432    -1.432674            1
# ...          ...          ...          ...
# 2896    0.025429     0.781389            0
# 2897    0.024129     2.007130            0
# 2898    0.022629    -0.449377            0
# 2899    0.020897     0.301111            0
# 2900    0.019315    -0.648971            0
#
# [2901 rows x 12 columns]

# %% [markdown]
# <b> Minmax scaler

# %%
num_columns = ["daily_returns", "momentum30", "momentum60", "momentum120", "vs_quantile", "divergence", "lag_returns"]
df = mmscaler(df = df, columns = num_columns)
df
# Out:
#      daily_returns momentum30 momentum60 momentum120 vs_quantile divergence  \
# 0         0.584934   0.441176   0.404351    0.350211    0.588236   0.393218
# 1         0.565414   0.492704    0.40173    0.351646    0.587818   0.391574
# 2         0.392206   0.383893   0.297372    0.288934    0.478561   0.386246
# 3         0.505109    0.39344   0.270697    0.270457    0.567238   0.382988
# 4         0.557234    0.39987   0.271061    0.254956     0.58753   0.380228
# ...            ...        ...        ...         ...         ...        ...
# 2896      0.643938    0.60479   0.634489    0.532002    0.604708   0.682735
# 2897      0.544794   0.586659   0.616354    0.537105    0.586278   0.676053
# 2898      0.575083   0.593992    0.64326    0.526309    0.587595   0.668345
# 2899      0.536739   0.572479   0.622585    0.520089    0.585133   0.659443
# 2900       0.55221   0.577462   0.620582     0.52179    0.587886   0.651312
#
#      lag_returns        Date     Index  vs_quantile_binary  \
# 0       0.474406  2010-06-25  4.579647               False
# 1       0.584934  2010-06-28  4.580263               False
# 2       0.565414  2010-06-29  4.537961                True
# 3       0.392206  2010-06-30  4.523635               False
# 4       0.505109  2010-07-01  4.522223               False
# ...          ...         ...       ...                 ...
# 2896    0.594467  2021-12-27   7.33883               False
# 2897    0.643938  2021-12-28  7.334336               False
# 2898    0.544794  2021-12-29  7.337347               False
# 2899    0.575083  2021-12-30  7.330857               False
# 2900    0.536739  2021-12-31  7.328201               False
#
#      vs_quantile_binary_freq  sell_signal
# 0                   0.083333         True
# 1                   0.083333         True
# 2                        0.1         True
# 3                        0.1         True
# 4                        0.1         True
# ...                      ...          ...
# 2896                0.033333        False
# 2897                0.033333        False
# 2898                0.033333        False
# 2899                0.033333        False
# 2900                0.033333        False
#
# [2901 rows x 12 columns]

# %% [markdown]
# <b> Specify model and set up cross validator

# %%
# Decision Tree Classifier

model = DecisionTreeClassifier()

# %%
# Specify dependent variable and predictors

y = df.loc[:,"sell_signal"]
X = df.loc[:, df.columns.drop(["Date","Index","sell_signal"])]

# %%
# Cross Validator

cv = StratifiedKFold(n_splits = 10, shuffle=True, random_state=123)

# Generate train and test sets using stratified K-fold splits, decide if number of positive classes in train/test splits is sufficient

for train_idx, test_idx in cv.split(X,y):
    # print(train_idx)
    train_X, test_X = X.loc[train_idx, :], X.loc[test_idx,:]
    train_y, test_y = y[train_idx], y[test_idx]

    train_0, train_1 = len(train_y[train_y==0]), len(train_y[train_y==1])
    test_0, test_1 = len(test_y[test_y==0]), len(test_y[test_y==1])

    print(">Train: 0=%d, 1=%d, Test: 0=%d, 1=%d" % (train_0, train_1, test_0, test_1))
# Out:
# >Train: 0=2231, 1=379, Test: 0=248, 1=43
# >Train: 0=2232, 1=379, Test: 0=247, 1=43
# >Train: 0=2231, 1=380, Test: 0=248, 1=42
# >Train: 0=2231, 1=380, Test: 0=248, 1=42
# >Train: 0=2231, 1=380, Test: 0=248, 1=42
# >Train: 0=2231, 1=380, Test: 0=248, 1=42
# >Train: 0=2231, 1=380, Test: 0=248, 1=42
# >Train: 0=2231, 1=380, Test: 0=248, 1=42
# >Train: 0=2231, 1=380, Test: 0=248, 1=42
# >Train: 0=2231, 1=380, Test: 0=248, 1=42

# %%
# Stratified K-Fold cross validation using F1 stat as model evaluation metric - focus on minority class
# Fit using all features

scores = cross_val_score(model, X, y, scoring = "f1", cv = cv, n_jobs = -1)
print("F1 score: %.3f (%.3f)" % (np.mean(scores), np.std(scores)))
# Out:
# F1 score: 0.815 (0.051)

# %% [markdown]
# <b> Feature Selection</b>
# Can model perform better on limited number of features?

# %%
# Create dictionary to store selected features

feature_selection = {}
feature_selection["Features_set"] = X.columns.tolist()

# %% [markdown]
# <font size = 3><u> 1. Variance treshold optimization

# %%
# Parameters optimization

pipe = Pipeline(
    [("selector", VarianceThreshold()),("classifier",model)]
)

parameters = {
    "selector__threshold": [0.001, 0.0025, 0.005, 0.007, 0.01, 0.02, 0.03]   
}

grid = GridSearchCV(pipe, parameters, cv = cv, scoring = "f1").fit(X,y)

print(grid.best_params_)
print(grid.best_estimator_)
pd.DataFrame.from_dict(grid.cv_results_, orient = "columns")
# Out:
# {'selector__threshold': 0.005}
# Pipeline(steps=[('selector', VarianceThreshold(threshold=0.005)),
#                 ('classifier', DecisionTreeClassifier())])
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.046357      0.005389         0.006203        0.001888
# 1       0.037764      0.002945         0.005700        0.001348
# 2       0.036458      0.003137         0.006932        0.001390
# 3       0.028797      0.002040         0.004604        0.001018
# 4       0.026302      0.002101         0.005098        0.001226
# 5       0.016399      0.001854         0.005702        0.001901
# 6       0.010202      0.002856         0.005398        0.002108
#
#   param_selector__threshold                           params  \
# 0                     0.001   {'selector__threshold': 0.001}
# 1                    0.0025  {'selector__threshold': 0.0025}
# 2                     0.005   {'selector__threshold': 0.005}
# 3                     0.007   {'selector__threshold': 0.007}
# 4                      0.01    {'selector__threshold': 0.01}
# 5                      0.02    {'selector__threshold': 0.02}
# 6                      0.03    {'selector__threshold': 0.03}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.818182           0.833333           0.886364           0.767442
# 1           0.827586           0.819277           0.894118           0.746988
# 2           0.876404           0.873563           0.904762           0.827586
# 3           0.813953           0.755556           0.717949           0.715789
# 4           0.800000           0.755556           0.716049           0.702128
# 5           0.363636           0.452381           0.463415           0.408602
# 6           0.310345           0.222222           0.290909           0.218182
#
#    split4_test_score  split5_test_score  split6_test_score  split7_test_score  \
# 0           0.814815           0.755556           0.765957           0.804878
# 1           0.795181           0.750000           0.739130           0.823529
# 2           0.790698           0.833333           0.758621           0.829268
# 3           0.839506           0.777778           0.791209           0.767442
# 4           0.823529           0.760870           0.760870           0.809524
# 5           0.250000           0.337349           0.384615           0.414634
# 6           0.208333           0.262295           0.290909           0.290909
#
#    split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0           0.850000           0.823529         0.812006        0.038665
# 1           0.864198           0.819277         0.807928        0.048422
# 2           0.900000           0.857143         0.845138        0.044320
# 3           0.704225           0.829268         0.771268        0.045782
# 4           0.739726           0.843373         0.771162        0.044167
# 5           0.355556           0.375000         0.380519        0.058174
# 6           0.148148           0.163265         0.240552        0.054164
#
#    rank_test_score
# 0                2
# 1                3
# 2                1
# 3                4
# 4                5
# 5                6
# 6                7

# %%
# Variance Threshold with optimized selector__threshold 0.005

pipe = Pipeline(
    [("selector", VarianceThreshold(threshold=0.005)), ("classifier", model)]
)

pipe.fit(X,y)
mask = pipe.named_steps["selector"].get_support()
features = X.columns[mask]

feature_selection["VarianceThreshold"] = features.tolist()

# %% [markdown]
# <font size = 3><u> 2. KBest univariate feature selection (chi2 test) optimization

# %%
# Parameters optimization

pipe = Pipeline([
    ("selector", SelectKBest(chi2)), ("classifier",model)
])

parameters = {"selector__k": range(1, X.shape[1])}

grid = GridSearchCV(pipe, parameters, cv=cv, scoring="f1").fit(X,y)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'selector__k': 6}
# Pipeline(steps=[('selector',
#                  SelectKBest(k=6,
#                              score_func=<function chi2 at 0x0000027F6AE9B1F0>)),
#                 ('classifier', DecisionTreeClassifier())])

# %%
grid_output = pd.DataFrame.from_dict(grid.cv_results_, orient="columns")
plt.plot(range(1,X.shape[1]), grid_output.mean_test_score)
plt.title("F1 score @ number of features")
# Out:
# Text(0.5, 1.0, 'F1 score @ number of features')

# %%
pipe = Pipeline([("selector", SelectKBest(chi2, k = 6)), ("classifier",model)])

pipe.fit(X,y)
mask = pipe.named_steps["selector"].get_support()
features = X.columns[mask]

feature_selection["KBest_chi2"] = features.tolist()

# %% [markdown]
# <font size = 3><u> 3. KBest univariate feature selection (f_classif test) optimization

# %%
# Parameters optimization

pipe = Pipeline([
    ("selector", SelectKBest(f_classif)), ("classifier",model)
])

parameters = {"selector__k": range(1, X.shape[1])}

grid = GridSearchCV(pipe, parameters, cv=cv, scoring="f1").fit(X,y)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'selector__k': 6}
# Pipeline(steps=[('selector', SelectKBest(k=6)),
#                 ('classifier', DecisionTreeClassifier())])

# %%
grid_output = pd.DataFrame.from_dict(grid.cv_results_, orient="columns")
plt.plot(range(1,X.shape[1]), grid_output.mean_test_score)
plt.title("F1 score @ number of features")
# Out:
# Text(0.5, 1.0, 'F1 score @ number of features')

# %%
pipe = Pipeline([("selector", SelectKBest(f_classif, k = 6)), ("classifier",model)])

pipe.fit(X,y)
mask = pipe.named_steps["selector"].get_support()
features = X.columns[mask]

feature_selection["KBest_ftest"] = features.tolist()

# %% [markdown]
# <font size = 3><u> 4. Recursive feature elimination optimization

# %%
pipe = Pipeline([("selector", RFE(model, step = 1)),("classifier", model)])

parameters = {"selector__n_features_to_select": range(1, X.shape[1])}

grid = GridSearchCV(pipe, parameters, cv = cv, scoring = "f1").fit(X,y)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'selector__n_features_to_select': 5}
# Pipeline(steps=[('selector',
#                  RFE(estimator=DecisionTreeClassifier(),
#                      n_features_to_select=5)),
#                 ('classifier', DecisionTreeClassifier())])

# %%
grid_output = pd.DataFrame.from_dict(grid.cv_results_, orient = "columns")
plt.plot(range(1,X.shape[1]), grid_output.mean_test_score)
plt.title("F1 score @ number of features")
# Out:
# Text(0.5, 1.0, 'F1 score @ number of features')

# %%
pipe = Pipeline([("selector", RFE(model, n_features_to_select = 5, step = 1)), ("classifier", model)])

pipe.fit(X,y)
mask = pipe.named_steps["selector"].get_support()
features = X.columns[mask]

feature_selection["RFE"] = features.tolist()

# %% [markdown]
# <font size = 3><u> 5. Select From Model optimization

# %%
pipe = Pipeline([("selector", SelectFromModel(model)), ("classifier", model)])

parameters = {"classifier__max_features": np.arange(1,X.shape[1])}

grid = GridSearchCV(pipe, parameters, cv = cv, scoring = "f1").fit(X,y)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'classifier__max_features': 5}
# Pipeline(steps=[('selector',
#                  SelectFromModel(estimator=DecisionTreeClassifier())),
#                 ('classifier', DecisionTreeClassifier(max_features=5))])

# %%
grid_output = pd.DataFrame.from_dict(grid.cv_results_, orient = "columns")
plt.plot(range(1,grid_output.shape[0]+1), grid_output.mean_test_score)
plt.title("F1 score @ number of features")
# Out:
# Text(0.5, 1.0, 'F1 score @ number of features')

# %%
# Model with max_features = 5

model_f5 = DecisionTreeClassifier(max_features = 5)

pipe = Pipeline([("selector", SelectFromModel(model_f5)), ("classifier", model_f5)])

pipe.fit(X,y)
mask = pipe.named_steps["selector"].get_support()

features = X.columns[mask]

feature_selection["SelectFromModel"] = features.tolist()

# %% [markdown]
# <font size = 3><u> 6. Sequential Feature Selector optimization
# \>> forward

# %%
pipe = Pipeline([("selector", SequentialFeatureSelector(model, n_features_to_select = "auto", direction = "forward")), ("classifier", model)])

pipe.fit(X,y)
mask = pipe.named_steps["selector"].get_support()
features = X.columns[mask]

feature_selection["forward_select"] = features.tolist()

# %% [markdown]
# <font size = 3><u> 6. Sequential Feature Selector optimization
# \>> backward

# %%
pipe = Pipeline([("selector", SequentialFeatureSelector(model, n_features_to_select = "auto", direction = "backward")), ("classifier", model)])

pipe.fit(X,y)
mask = pipe.named_steps["selector"].get_support()
features = X.columns[mask]

feature_selection["backward_select"] = features.tolist()

# %% [markdown]
# <font size = 3><u> Best subset classification according to F1 score

# %%
# Default model

cv = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 1)
model = DecisionTreeClassifier()

pipe = Pipeline([("classifier", model)])

f1_scores = {}
for key in feature_selection.keys():
    columns = feature_selection[key]
    x = X[columns]
    scores = cross_val_score(pipe, x, y, cv=cv, scoring = "f1", n_jobs=-1)
    score = np.mean(scores)
    f1_scores[key] = score

sorted(f1_scores.items(), key = lambda item: item[1], reverse = True)
# Out:
# [('RFE', 0.8667585850443127),
#  ('KBest_chi2', 0.8612083187972361),
#  ('VarianceThreshold', 0.855640880568566),
#  ('Features_set', 0.8183098570563061),
#  ('KBest_ftest', 0.7515197132670698),
#  ('backward_select', 0.6936942793450145),
#  ('forward_select', 0.6933888259808871),
#  ('SelectFromModel', 0.6069453792881827)]

# %%
# Model with max_features = 5

cv = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 1)
model = DecisionTreeClassifier(max_features=5)

pipe = Pipeline([("classifier", model)])

f1_scores = {}
for key in feature_selection.keys():
    columns = feature_selection[key]
    x = X[columns]
    scores = cross_val_score(pipe, x, y, cv=cv, scoring = "f1", n_jobs=-1)
    score = np.mean(scores)
    f1_scores[key] = score

sorted(f1_scores.items(), key = lambda item: item[1], reverse = True)
# Out:
# [('RFE', 0.8606200921931564),
#  ('KBest_chi2', 0.8468748889964918),
#  ('VarianceThreshold', 0.8202771648827796),
#  ('Features_set', 0.7793423420534369),
#  ('KBest_ftest', 0.7272633712514393),
#  ('backward_select', 0.7042006599193165),
#  ('forward_select', 0.6879099965814257),
#  ('SelectFromModel', 0.621948506488251)]

# %% [markdown]
# Best F1 score is achieved with RFE subset for default model

# %% [markdown]
# <font size = 3><u> Put it all together: rank features according to their presence in different filtering methods

# %%
features_df = pd.DataFrame({"Feature": feature_selection["Features_set"]})

filter_methods = list(feature_selection.keys())[1:]

for filter in filter_methods:
    features_df.loc[:, filter] = False
    features_df.loc[features_df["Feature"].isin(feature_selection[filter]),filter] = True

features_df["COUNT"] = features_df.iloc[:,1:].sum(axis = 1) # add COUNT column
features_df.sort_values(by=["COUNT"], ascending = False, inplace = True) # sort by COUNT column in descending order
features_df = features_df.reset_index(drop=True)
features_df
# Out:
#                    Feature  VarianceThreshold  KBest_chi2  KBest_ftest    RFE  \
# 0               momentum60               True        True         True   True
# 1               momentum30               True        True         True   True
# 2       vs_quantile_binary               True        True         True  False
# 3  vs_quantile_binary_freq               True        True        False   True
# 4              momentum120               True        True         True   True
# 5               divergence               True        True         True   True
# 6            daily_returns              False       False         True  False
# 7              lag_returns              False       False        False  False
# 8              vs_quantile              False       False        False  False
#
#    SelectFromModel  forward_select  backward_select  COUNT
# 0             True            True             True      7
# 1             True           False            False      5
# 2            False            True             True      5
# 3            False            True             True      5
# 4            False           False            False      4
# 5            False           False            False      4
# 6            False            True             True      3
# 7            False           False             True      1
# 8            False           False            False      0

# %%
# According to F1 score RFE subset is superior.
# Can the result be improved with subset >5? 

model = DecisionTreeClassifier()
pipe = Pipeline([("classifier", model)])

features1 = features_df.loc[features_df.COUNT >= 5,"Feature"].tolist()
features1

x = X[features1]

scores = cross_val_score(pipe, x, y, cv=cv, scoring = "f1", n_jobs=-1)
score = np.mean(scores)
print("Score for feature1 subset: %.3f" % score)
# Out:
# Score for feature1 subset: 0.731

# %%
# Can the result be improved with subset >3?

features2 = features_df.loc[features_df.COUNT >= 3,"Feature"].tolist()
features2

x = X[features2]

scores = cross_val_score(pipe, x, y, cv=cv, scoring = "f1", n_jobs=-1)
score = np.mean(scores)
print("Score for feature2 subset: %.3f" % score)
# Out:
# Score for feature2 subset: 0.837

# %%
# Neither feature1 nor feature2 subset outperformed RFE subset. Hence, continue with second.

# %% [markdown]
# <b> Model Optimization </b>
# Select appropriate max_depth for VarianceThreshold features

# %%
# Extract feature names - ultimate set

features = feature_selection["RFE"]
x = X[features]

# %%
# Optimize model with respect to max_depth

model = DecisionTreeClassifier()
pipe = Pipeline([("classifier", model)])

parameters = {"classifier__max_depth": np.arange(1,10,1)}

grid = GridSearchCV(pipe, parameters, cv = cv, scoring = "f1").fit(x,y)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'classifier__max_depth': 9}
# Pipeline(steps=[('classifier', DecisionTreeClassifier(max_depth=9))])

# %%
grid_output = pd.DataFrame.from_dict(grid.cv_results_, orient = "columns")
plt.plot(range(1,grid_output.shape[0]+1), grid_output.mean_test_score)
plt.title("F1 score @ number of features")
# Out:
# Text(0.5, 1.0, 'F1 score @ number of features')

# %%
# Model with max_depth = 9

# %% [markdown]
# <b> Model Diagnostics </b>

# %%
# Extract feature names - ultimate set

features = feature_selection["RFE"]
features
# Out:
# ['momentum30',
#  'momentum60',
#  'momentum120',
#  'divergence',
#  'vs_quantile_binary_freq']

# %%
# Set X and y variables for logistic regression 

y = df.loc[:,"sell_signal"]
X = df.loc[:, features]

# %%
# Fit Decision Tree using subset of variables

model = DecisionTreeClassifier(max_depth = 9)
res = model.fit(X,y)

# %%
# Predict using specified model, assuming default threshold of 0.5

predict = res.predict_proba(X)
predict_proba = res.predict_proba(X)[:, 1]
predict_class = [True if x > 0.5 else False for x in predict_proba]

# %%
# Model diagnostics on 10-fold stratified data

pipe = Pipeline([("classifier", model)])

ys = []
probabilities = []
classes = []

for train, test in cv.split(X,y):
    X_train, X_test = X.loc[train,:], X.loc[test,:]
    y_train, y_test = y[train], y[test]

    pipe.fit(X_train,y_train)
    probability_test = pipe.predict_proba(X_test)[:,1]
    class_test = [True if x > 0.5 else False for x in probability_test]

    ys += y_test.tolist()
    probabilities += probability_test.tolist()
    classes += class_test

# %%
# Perform model CV diagnostics 

ClassificationDiagnostics(ys, classes, probabilities).plotDiagnostics()

# %%
# Finding optimal threshold for ROC curve - G-Mean

fpr, tpr, thresholds = roc_curve(ys, probabilities)

gmeans = np.sqrt(tpr * (1 - fpr))
idx = np.argmax(gmeans)
print("Best threshold = %f, G-Mean = %.3f" % (thresholds[idx], gmeans[idx]))
# Out:
# Best threshold = 0.090909, G-Mean = 0.908

# %%
# G-Mean outputs threshold of = 0.090909. For this value, let's reprint diagnostics

threshold = thresholds[idx]
classes = [True if x >= threshold else False for x in probabilities]

ClassificationDiagnostics(ys, classes, probabilities).plotDiagnostics()

# %%
# Finding optimal threshold for ROC curve - Youden's J statistic

fpr, tpr, thresholds = roc_curve(ys, probabilities)

J = tpr - fpr
idx = np.argmax(J)
print("Best threshold = %f, J = %.3f" % (thresholds[idx], J[idx]))
# Out:
# Best threshold = 0.200000, J = 0.819

# %%
# J-stat outputs threshold of = 0.20000. For this value, let's reprint diagnostics

threshold = thresholds[idx]
classes = [True if x >= threshold else False for x in probabilities]

ClassificationDiagnostics(ys, classes, probabilities).plotDiagnostics()

# %%
# Finding optimal threshold for PR curve - F-Measure

precision, recall, thresholds = precision_recall_curve(ys, probabilities)

fscore = (2 * precision * recall) / (precision + recall)
idx = np.argmax(fscore)
print("Best threshold = %f, F-Score = %.3f" % (thresholds[idx], fscore[idx]))
# Out:
# Best threshold = 0.683333, F-Score = 0.855

# %%
# FMeasure outputs threshold of = 0.272727. For this value, let's reprint diagnostics

threshold = thresholds[idx]
classes = [True if x >= threshold else False for x in probabilities]

ClassificationDiagnostics(ys, classes, probabilities).plotDiagnostics()

# %% [markdown]
# <b> Plot Decision Tree </b>

# %%
fig, ax = plt.subplots(figsize = (25,10))

_ = tree.plot_tree(model, feature_names = features, class_names = ["Not Sell","Sell"], filled = True, fontsize = 8)

# %% [markdown]
# <b> WORKINGS
